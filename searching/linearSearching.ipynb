# %%
def linearSearching(arr, item):
    for i in range(len(arr)):
        if arr[i]==item:
            return i
    return "not found"

# %%
a=[39, 54, 656, 34,22]

# %%
print(linearSearching(a, 222))
# Out:
# not found

# %%
print(linearSearching(a, 22))
# Out:
# 4
